# %% [markdown]
# ## Ground State of Spin-1/2 Systems

# %%
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
def createBasis(N):
    return np.array(range(2**N))

def getIndex(state):
    return np.where(states == state)

def bin(x):
    return f'{x:0{N}b}'

# %%
N = 3
states = createBasis(N)

list(zip(states,[bin(i) for i in states]));

# %%
def spin_z(state,index):
    return 1 if (state & (1<<index)) != 0 else -1

def spin_z_z1_open(state,N):
    spins = np.array([1 if (state & (1<<index)) != 0 else -1 for index in range(N)])[::-1]
    return sum(np.multiply(spins[:-1],spins[1:]))
    
    
dict(zip([bin(state) for state in states],[[spin_z(state,index) for index in range(N)] for state in states]));

# %%
def spin_x(state,index):
    return state ^ (1<<index)
dict(zip([bin(state) for state in states],[[bin(spin_x(state,index)) for index in range(N)] for state in states]));

# %%
def hamiltonian_openBoundry(J = 1,g = 0.5,N = 3):
    
    states = createBasis(N)
    
    H = sp.sparse.lil_matrix((2**N,2**N))

    for state in states:
        
        H[state,state] = -J*spin_z_z1_open(state,N)
        
        sx = [spin_x(state,s) for s in range(N)]
        for i in sx:
            H[state,i] = -g
            
    return H

# %%
def groundState(J = 1, g = 0,N = 5):
    H = hamiltonian(J,g,N)
    return sp.sparse.linalg.eigsh(H,k = 1,which='SA',return_eigenvectors=False)

# %%
#Hamiltonian
J,g,N = 1,0.5,15
H = hamiltonian_openBoundry(J,g,N)

#K = H.asformat("array")
#K, (K == K.T).all()

gs,gs_vec = sp.sparse.linalg.eigsh(H,k = 1,which='SA')

gs#,gs_vec
# Out:
# array([-15.08251799])

# %% [markdown]
# ### Results

# %%
J,g,N = 1,0.5,10
H = hamiltonian_openBoundry(J,g,N)

print("Formulated Matrix")

energy,energy_vec = sp.sparse.linalg.eigsh(H,k = 2**(N-1),which='SA')
energy = energy[0:-1:int(2**(N-1)/5)]
energy_vec = energy_vec[0:-1:int(2**(N-1)/5)]

print("PRINTING")

energy_vec = energy_vec.T

fig = plt.figure()

for e,vec in zip(energy,energy_vec):
    #vec /= np.sqrt(np.sum(vec**2))
    plt.plot(list(range(len(vec))),vec**2,label = f'{e:.2f}')
    
plt.legend()
plt.ylim(0,1)
plt.grid()
plt.ylabel("Probability")
plt.xlabel("State")
plt.title(f"Probability Distribution for Different Energy States \n J = {J} g = {g} N = {N}")
plt.show()
# Out:
# Formulated Matrix
# PRINTING

# %%
J,g = 1,0.5
N = list(range(2,6))

H = [hamiltonian_openBoundry(J,g,n) for n in N]

GS = [sp.sparse.linalg.eigsh(h,k = 1,which='SA') for h in H]


print("PRINTING")

fig = plt.figure()

for gs,gs_vec in GS:
    gs_vec = gs_vec.T
    for e,vec in zip(gs,gs_vec):
        vec /= np.sqrt(np.sum(vec**2))
        plt.plot(list(range(len(vec))),vec**2,label = f'{e:.2f}')
    
plt.legend()
plt.ylim(0,1)
plt.grid()
plt.ylabel("Probability")
plt.xlabel("State")
plt.title(f"Ground State for Various N \n J = {J} g = {g} \n N = {N}")
plt.show()
# Out:
# PRINTING

# %%
J,N = 3,8
G = np.linspace(0,20,10)

H = [hamiltonian_openBoundry(J,g,N) for g in G]

GS = [sp.sparse.linalg.eigsh(h,k = 1,which='SA',return_eigenvectors=False) for h in H]

print("PRINTING")

fig = plt.figure()

for g,gs in zip(G,GS):
    plt.scatter(g,gs,label = f'{g:.1f}')

plt.legend()
#plt.ylim(0,1)
plt.grid()
plt.ylabel("Ground State")
plt.xlabel("g")
plt.title(f"Ground State for Various g \n J = {J} N = {N}")
plt.show()
# Out:
# PRINTING
