# %% [markdown]
# ### Matrix Product States

# %%
import numpy as np
import scipy as sp

from ED_Functions import vec_norm,Hamiltonian_TFIM_open,groundState_Krylov

import time
import matplotlib.pyplot as plt

# %%
J,g,N = 1,0.5,8

L = 50

H,basis = Hamiltonian_TFIM_open(J,g,N,return_basis=True)

gs,psi = groundState_Krylov(J,g,N,L)
gs,psi;

# %%
#MPS

bondDim = 10

A,B = [],[]
mps = np.empty((10,10,len(psi)))

# %%
#D = int(2**(np.log2(len(psi))//2))
D = N
PSI = psi.reshape(2,(2**(D-1)))
PSI.shape
# Out:
# (2, 128)

# %%
U,S,Vh = sp.linalg.svd(PSI,full_matrices=False)
#if(len(S) > bondDim):
#    U = U[:bondDim,:bondDim]
#    S = S[:bondDim]
#    Vh = Vh[:bondDim,:bondDim]
U.shape,S.shape,Vh.shape
# Out:
# ((2, 2), (2,), (2, 128))

# %%
(((U@np.diag(S)@Vh) - PSI) < 1e-9).all()
# Out:
# np.True_

# %%
K = S@Vh
K.shape
# Out:
# (16,)

# %%
U
# Out:
# array([[-0.95989772,  0.09666593, -0.00309233,  0.13060741,  0.01242421,
#         -0.01425283, -0.04642849,  0.036256  ,  0.02942407,  0.08141118],
#        [-0.0894117 , -0.0452893 , -0.61675713, -0.07825494, -0.00729882,
#          0.35451518,  0.30475095, -0.14042099,  0.05612704, -0.23951756],
#        [-0.09057304, -0.00678917, -0.05167107,  0.01210702, -0.16959626,
#         -0.21589534, -0.20419316, -0.12619654, -0.33867354,  0.32478057],
#        [ 0.0200922 , -0.07706766, -0.61306692, -0.19753075, -0.04833225,
#         -0.23046065, -0.00797911, -0.33547598, -0.16394623,  0.15148583],
#        [-0.11448929,  0.00669968,  0.05505928, -0.06966428,  0.039452  ,
#         -0.2602722 ,  0.10978692,  0.12746124, -0.17587892, -0.31498091],
#        [-0.01170815, -0.03445991, -0.07267489, -0.07160824, -0.0740058 ,
#         -0.11460109, -0.73025115, -0.15306254,  0.20042742, -0.54178463],
#        [ 0.00870006, -0.01928586,  0.0435037 , -0.109207  , -0.06328036,
# ...

# %%
def matripProductState(psi,bondDim):
    A = np.empty()
    x = int(np.sqrt(len(psi)))
    B = np.reshape(x,x)

    return A
