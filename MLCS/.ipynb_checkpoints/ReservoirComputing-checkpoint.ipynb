# %% [markdown]
# ### Reservoir Computing

# %%
import numpy as np
import scipy as sp
import networkx as nx
from sklearn import linear_model

from my_attractors import *

import matplotlib.pyplot as plt
import ipywidgets.widgets as widget

# %%
X = np.load("lorenz63_sim_data_e3_3.npy")
X.shape
# Out:
# (10000, 3)

# %%
# Creating the Reservoir - RNN

n = 500
p = 0.1
network = nx.fast_gnp_random_graph(n,p,seed = 100)
network = nx.to_numpy_array(network,dtype = float)
network.shape
# Out:
# (500, 500)

# %%
# Varying connections b/w [-1,1]

rng = np.random.default_rng(100)
network = np.multiply(network, rng.random(size = network.shape)*2 - 1)
network.shape
# Out:
# (500, 500)

# %%
# Scaling Spectral Radius; 0.4 for Lorenz

s = 0.4

K = sp.sparse.coo_matrix(network)
evals = sp.sparse.linalg.eigs(K,k = 1,v0 = np.ones(n),return_eigenvectors=False)

A = network * s/np.max(np.abs(evals))
A.shape
# Out:
# (500, 500)

# %%
rng2 = np.random.default_rng(101)
W_in = rng.uniform(low = -0.1, high = 0.1,size = (n,3))
W_in.shape
# Out:
# (500, 3)

# %%
steps = 6000
disc = 1000
R = np.zeros((n,steps))
#R[:,i] ->  ri
R.shape
# Out:
# (500, 6000)

# %%
assert steps < len(X)
for i in range(steps-1):
    R[:,i+1] = np.tanh(A@R[:,i] + W_in @ X[i])
R = R[:,disc:]
#R = R[:,100:]
R.shape
# Out:
# (500, 5000)

# %%
# Target Matrix
Y = X[1:steps-disc+1,:]
Y
# Out:
# array([[-15.25797688, -20.51030618,  30.15606334],
#        [-16.06372202, -18.7186594 ,  34.62178262],
#        [-16.27027628, -15.60166621,  38.27016227],
#        ...,
#        [  0.25295104,   0.69233373,  16.04055565],
#        [  0.33773937,   0.75128216,  15.21163364],
#        [  0.4201908 ,   0.8354887 ,  14.42746054]], shape=(5000, 3))

# %%
reg = linear_model.Ridge(alpha = 1e-8,fit_intercept=False)
reg.fit(R.T,Y)
W_out = reg.coef_.T
W_out.shape
# Out:
# (500, 3)

# %%
X_rec = (R.T@W_out)
plotTimeSeries([[X[:1000],{}],[X_rec[:1000],{}]]);
